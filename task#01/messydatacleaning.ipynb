# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv(r"Z:\Intermship\us-shein-beauty_and_health-4267.csv")
data.head(5000)
# Out:
#                                  goods-title-link--jump  \
# 0     90ML 3.0FL.OZ Fragrance Hair & Body Mist Vanil...
# 1     SHEGLAM Color Bloom Liquid Blush Matte Finish-...
# 2                  1pc Silicone Facial Massage Ice Tray
# 3     5Ml Bottom Refillable Perfume Bottle With Pump...
# 4     12pcs Multi-Functional Makeup Brush Set Includ...
# ...                                                 ...
# 4261                                                NaN
# 4262                                                NaN
# 4263                                                NaN
# 4264                                                NaN
# 4265                                                NaN
#
#                             goods-title-link--jump href  selling_proposition  \
# 0     https://us.shein.com/90ML-3-0FL-OZ-Fragrance-H...    30+ sold recently
# 1     https://us.shein.com/SHEGLAM-Color-Bloom-Liqui...                  NaN
# ...

# %%
print(data.isnull().sum())
# Out:
# goods-title-link--jump         4227
# goods-title-link--jump href    4227
# selling_proposition            1009
# price                             0
# discount                        282
# color-count                    3060
# rank-title                     3428
# rank-sub                       3428
# goods-title-link                 39
# dtype: int64

# %%
datatype=data['price'].dtype
print(datatype)
data['price'] = data['price'].str.replace('$', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
# ...
