# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

kernel = np.ones((3,3))

erosion = cv2.erode(image, kernel, iterations=1)

dilation = cv2.dilate(image, kernel, iterations=1)

opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

titles = ['Original Image', 'Erosion', 'Dilation', 'Opening', 'Closing']
images = [image, erosion, dilation, opening, closing]

for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_16236\4189037894.py:5: SyntaxWarning: invalid escape sequence '\I'
#   image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_16236\2259273642.py:1: SyntaxWarning: invalid escape sequence '\I'
#   img=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

# %%
kernel=np.ones((3,3))

# %%
erode=cv2.erode(img,kernel,iterations=1)

# %%
opening=cv2.morphologyEx(erode,cv2.MORPH_OPEN,kernel)

# %%
dilate=cv2.dilate(opening,kernel,iterations=1)

# %%
closing=cv2.morphologyEx(dilate,cv2.MORPH_CLOSE,kernel)

# %%
plt.imshow(closing,cmap='gray')
plt.show()

# %%
  # erode=morph_erode(img)
  #   open=morph_open(erode)
  #   dilate=morph_dilate(open)
  #   denoise_img=morph_close(dilate)
  #   return denoise_img

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

blurred=cv2.GaussianBlur(image,(3,3),0)
a,binary=cv2.threshold(blurred,127,255,cv2.THRESH_BINARY)
kernel = np.ones((3,3))

opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)

# titles = ['Original Image', 'Erosion', 'Dilation', 'Opening', 'Closing']
# images = [image, erosion, dilation, opening, closing]

# for i in range(5):
#     plt.subplot(2, 3, i+1)
#     plt.imshow(images[i], cmap='gray')
#     plt.title(titles[i])
#     plt.xticks([]), plt.yticks([])
plt.imshow(closing,cmap='grey')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_16236\3733639598.py:5: SyntaxWarning: invalid escape sequence '\I'
#   image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)
