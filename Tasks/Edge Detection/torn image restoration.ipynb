# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")
image = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
blurred_image=cv2.GaussianBlur(image,(9,9),0)
edges=cv2.Canny(blurred_image, 0,50)

plt.title('image before')
plt.imshow(image1)
plt.show()

plt.title('after image')
plt.imshow(edges, cmap='gray')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_7132\2874502178.py:1: SyntaxWarning: invalid escape sequence '\I'
#   image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")

# %%
image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")
image = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
blurred_image=cv2.GaussianBlur(image,(9,9),0)
edge2=cv2.Sobel(src=blurred_image,ddepth=cv2.CV_64F,dx=1,dy=1)


plt.title('image before')
plt.imshow(image1)
plt.show()

plt.title('after image')
plt.imshow(edge2, cmap='gray')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_7132\1730522242.py:1: SyntaxWarning: invalid escape sequence '\I'
#   image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")

# %%
image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")
image = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
blurred_image=cv2.GaussianBlur(image,(9,9),0)
edge2=cv2.Scharr(src=blurred_image,ddepth=cv2.CV_64F,dx=1,dy=0)

plt.title('image before')
plt.imshow(image1)
plt.show()

plt.title('after image')
plt.imshow(edge2, cmap='gray')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_7132\1686241565.py:1: SyntaxWarning: invalid escape sequence '\I'
#   image1=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic1.jpeg")
